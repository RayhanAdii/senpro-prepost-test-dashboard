# %%
import pandas as pd

# Replace 'data.xlsx' with the path to your Excel file.
df = pd.read_excel('../data/jawaban-pretest-posttest/Pre-Test-2.xlsx')

# %%
df.head()
# Out:
#    ID          Start time     Completion time  \
# 0   1 2025-02-13 18:23:58 2025-02-13 18:24:14
# 1   2 2025-02-13 18:43:24 2025-02-13 18:45:08
# 2   3 2025-02-13 18:47:25 2025-02-13 18:48:18
# 3   4 2025-02-13 19:06:48 2025-02-13 19:06:59
# 4   5 2025-02-14 07:20:24 2025-02-14 07:27:04
#
#                                       Email                        Name  \
# 0        agustinus.angelo2803@365.ugm.ac.id        agustinus.angelo2803
# 1  antonius.daiva.prabawisesa@365.ugm.ac.id  antonius.daiva.prabawisesa
# 2        rayhan.adi.wicaksono@365.ugm.ac.id        rayhan.adi.wicaksono
# 3                                 anonymous                         NaN
# 4                                 anonymous                         NaN
#
#    Total points  Quiz feedback                Nama  Points - Nama  \
# 0           NaN            NaN                   A            NaN
# 1           NaN            NaN               antok            NaN
# ...

# %%
df = df.drop(columns=[col for col in df.columns if col.startswith("Points") or col.startswith("Feedback")])

df = df.drop(['ID','Start time','Completion time','Email','Name','Total points','Quiz feedback'], axis=1)

# %%
df.rename(columns={'Nomor Kelompok. Format: {Nama kelas}_{Nomor kelompok}. Contoh: B1_05 atau B3_12': 'Nomor_Kelompok'}, inplace=True)

# %%
df.head()  # Display the first few rows of the DataFrame.
# Out:
#                  Nama                 NIM             Kelas Nomor_Kelompok  \
# 0                   A                   A  B1 (Lab Dasar 1)            NaN
# 1               antok                  21  B1 (Lab Dasar 1)             B5
# 2        Test - Rehan           21/477186  B1 (Lab Dasar 1)          B1_05
# 3                 AAA                  aa  B3 (Lab Dasar 3)             aa
# 4  Afix Vega Praditya  21/477810/TK/52629  B1 (Lab Dasar 1)          B1_01
#
#   Apa yang dimaksud dengan version control pada proses pengembangan perangkat lunak?  \
# 0                                                  A
# 1                                     biar gk pusing
# 2                                                Git
# 3                                                 aa
# 4  Version control adalah suatu sistematika untuk...
#
#                  Apa perbedaan ‘scrum’ dan ‘kanban’?  \
# 0                                                  A
# ...
