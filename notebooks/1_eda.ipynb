# %%
import pandas as pd

# Replace 'data.xlsx' with the path to your Excel file.
df = pd.read_excel('data/jawaban-pretest-posttest/Pre-Test-1.xlsx')

# %%
df.head()
# Out:
#    ID          Start time     Completion time      Email  Name  Total points  \
# 0   1 2025-02-15 07:09:59 2025-02-15 07:14:43  anonymous   NaN           NaN
# 1   2 2025-02-15 07:11:07 2025-02-15 07:14:57  anonymous   NaN           NaN
# 2   3 2025-02-15 07:09:55 2025-02-15 07:18:15  anonymous   NaN           NaN
# 3   4 2025-02-15 07:10:28 2025-02-15 07:18:29  anonymous   NaN           NaN
# 4   5 2025-02-15 07:10:31 2025-02-15 07:19:25  anonymous   NaN           NaN
#
#    Quiz feedback                                               Nama  \
# 0            NaN                           Abyyu Abdul Azhim Raihan
# 1            NaN                               Adzka Bagus Juniarta
# 2            NaN  Muhammad Fajrulfalaq Izzulfirdausyah Suryaprab...
# 3            NaN                          Gavind Muhammad Pramahita
# 4            NaN                                   Bagas Pujangkoro
#
#    Points - Nama  Feedback - Nama  ...  \
# 0            NaN              NaN  ...
# 1            NaN              NaN  ...
# 2            NaN              NaN  ...
# 3            NaN              NaN  ...
# 4            NaN              NaN  ...
#
#   Feedback - Sebutkan peran-peran yang terdapat dalam sebuah tim pengembangan aplikasi dan jelaskan tanggung jawab setiap peran tersebut!  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Permasalahan apa yang menurut Anda memiliki peluang untuk diselesaikan dengan solusi berbasis teknologi? Jelaskan teknologi seperti apa yang menurut Anda dapat menyelesaikan permasalahan tersebut!  \
# 0  Kemacetan dan sistem transportasi yang kurang ...
# 1  Salah satu permasalahan yang memiliki peluang ...
# 2  Salah satu permasalahan yang memiliki peluang ...
# 3  Pengelolaan sampah yang masih kurang efektif, ...
# 4  Salah satu permasalahan yang memiliki peluang ...
#
#    Points - Permasalahan apa yang menurut Anda memiliki peluang untuk diselesaikan dengan solusi berbasis teknologi? Jelaskan teknologi seperti apa yang menurut Anda dapat menyelesaikan permasalahan tersebut!  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - Permasalahan apa yang menurut Anda memiliki peluang untuk diselesaikan dengan solusi berbasis teknologi? Jelaskan teknologi seperti apa yang menurut Anda dapat menyelesaikan permasalahan tersebut!  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Bagaimana pandangan anda terhadap penggunaan teknologi untuk menyelesaikan masalah sehari-hari yang diimplementasikan oleh perusahaan-perusahaan startup di Indonesia? Pilihlah satu saja perusahaan...  \
# 0  Salah satu startup Indonesia yang berhasil men...
# 1  Salah satu startup di Indonesia yang menarik p...
# 2  Penggunaan teknologi untuk menyelesaikan masal...
# 3  Beberapa startup yang sudah sukses memiliki im...
# 4  Pandangan saya terhadap penggunaan teknologi u...
#
#    Points - Bagaimana pandangan anda terhadap penggunaan teknologi untuk menyelesaikan masalah sehari-hari yang diimplementasikan oleh perusahaan-perusahaan startup di Indonesia? Pilihlah satu saja perusahaan...  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - Bagaimana pandangan anda terhadap penggunaan teknologi untuk menyelesaikan masalah sehari-hari yang diimplementasikan oleh perusahaan-perusahaan startup di Indonesia? Pilihlah satu saja perusahaan...  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Apa yang anda ketahui tentang bussiness model canvas, lean canvas, dan lean startup? Cukup tuliskan saja apa yang anda ketahui, tidak perlu muluk-muluk.  \
# 0  Business Model Canvas (BMC)\nKerangka kerja ya...
# 1  Business Model Canvas adalah alat visual yang ...
# 2  Business Model Canvas (BMC) adalah kerangka ke...
# 3  BMC: Canvas untuk melakukan analysis baik inte...
# 4  1. Business Model Canvas (BMC)\n\nKerangka ker...
#
#    Points - Apa yang anda ketahui tentang bussiness model canvas, lean canvas, dan lean startup? Cukup tuliskan saja apa yang anda ketahui, tidak perlu muluk-muluk.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Feedback - Apa yang anda ketahui tentang bussiness model canvas, lean canvas, dan lean startup? Cukup tuliskan saja apa yang anda ketahui, tidak perlu muluk-muluk.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 31 columns]

# %%
df = df.drop(columns=[col for col in df.columns if col.startswith("Points") or col.startswith("Feedback")])

df = df.drop(['ID','Start time','Completion time','Email','Name','Total points','Quiz feedback'], axis=1)

# %%
df.rename(columns={'Nomor Kelompok. Format: {Nama kelas}_{Nomor kelompok}. Contoh: B1_05 atau B3_12': 'Nomor_Kelompok'}, inplace=True)

# %%
df.head()  # Display the first few rows of the DataFrame.
# Out:
#                                                 Nama                 NIM  \
# 0                           Abyyu Abdul Azhim Raihan  22/497717/TK/54562
# 1                               Adzka Bagus Juniarta  22/500276/TK/54824
# 2  Muhammad Fajrulfalaq Izzulfirdausyah Suryaprab...  22/494174/TK/54184
# 3                          Gavind Muhammad Pramahita  22/497221/TK/54484
# 4                                   Bagas Pujangkoro  22/496484/TK/54400
#
#               Kelas  \
# 0  B1 (Lab Dasar 1)
# 1  B3 (Lab Dasar 3)
# 2  B1 (Lab Dasar 1)
# 3  B1 (Lab Dasar 1)
# 4  B1 (Lab Dasar 1)
#
#   Nomor Kelompok. Format: {Nama kelas}_{Nomor kelompok}. Contoh: B1_05 atau B3_12  \
# 0                                              B1_11
# 1                                              B3_08
# 2                                              B1_09
# 3                                              B1_14
# 4                                              B1_14
#
#   Sebutkan peran-peran yang terdapat dalam sebuah tim pengembangan aplikasi dan jelaskan tanggung jawab setiap peran tersebut!  \
# 0  Product Manager\nMenentukan visi, roadmap, dan...
# 1  • Project Manager (PM) \nBerperan dalam manaje...
# 2  Dalam sebuah tim pengembangan aplikasi, terdap...
# 3  1. Project Manager\n- Mengelola jadwal proyek,...
# 4  1. Ketua Tim (Project Manager) – Mengatur pemb...
#
#   Permasalahan apa yang menurut Anda memiliki peluang untuk diselesaikan dengan solusi berbasis teknologi? Jelaskan teknologi seperti apa yang menurut Anda dapat menyelesaikan permasalahan tersebut!  \
# 0  Kemacetan dan sistem transportasi yang kurang ...
# 1  Salah satu permasalahan yang memiliki peluang ...
# 2  Salah satu permasalahan yang memiliki peluang ...
# 3  Pengelolaan sampah yang masih kurang efektif, ...
# 4  Salah satu permasalahan yang memiliki peluang ...
#
#   Bagaimana pandangan anda terhadap penggunaan teknologi untuk menyelesaikan masalah sehari-hari yang diimplementasikan oleh perusahaan-perusahaan startup di Indonesia? Pilihlah satu saja perusahaan...  \
# 0  Salah satu startup Indonesia yang berhasil men...
# 1  Salah satu startup di Indonesia yang menarik p...
# 2  Penggunaan teknologi untuk menyelesaikan masal...
# 3  Beberapa startup yang sudah sukses memiliki im...
# 4  Pandangan saya terhadap penggunaan teknologi u...
#
#   Apa yang anda ketahui tentang bussiness model canvas, lean canvas, dan lean startup? Cukup tuliskan saja apa yang anda ketahui, tidak perlu muluk-muluk.
# 0  Business Model Canvas (BMC)\nKerangka kerja ya...
# 1  Business Model Canvas adalah alat visual yang ...
# 2  Business Model Canvas (BMC) adalah kerangka ke...
# 3  BMC: Canvas untuk melakukan analysis baik inte...
# 4  1. Business Model Canvas (BMC)\n\nKerangka ker...
